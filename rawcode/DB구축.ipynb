# %%
# C:\Users\Owner\.conda  가상환경 디렉토리

# %%
# pip install yfinance

# %%
pip install yfinance
# Out:
# Processing c:\users\owner\appdata\local\pip\cache\wheels\7e\d5\f4\f628965651f61ae35c2bdc73571ce1a2026e1550a336b5ad4b\yfinance-0.1.59-py2.py3-none-any.whl
# Requirement already satisfied: requests>=2.20 in c:\users\owner\anaconda3\lib\site-packages (from yfinance) (2.24.0)
# Requirement already satisfied: numpy>=1.15 in c:\users\owner\anaconda3\lib\site-packages (from yfinance) (1.19.2)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\owner\anaconda3\lib\site-packages (from yfinance) (4.6.1)
# Requirement already satisfied: pandas>=0.24 in c:\users\owner\anaconda3\lib\site-packages (from yfinance) (1.1.3)
# Processing c:\users\owner\appdata\local\pip\cache\wheels\57\6d\a3\a39b839cc75274d2acfb1c58bfead2f726c6577fe8c4723f13\multitasking-0.0.9-py3-none-any.whl
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\owner\anaconda3\lib\site-packages (from requests>=2.20->yfinance) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\owner\anaconda3\lib\site-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\owner\anaconda3\lib\site-packages (from requests>=2.20->yfinance) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\owner\anaconda3\lib\site-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: pytz>=2017.2 in c:\users\owner\anaconda3\lib\site-packages (from pandas>=0.24->yfinance) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\owner\anaconda3\lib\site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\owner\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Installing collected packages: multitasking, yfinance
# Successfully installed multitasking-0.0.9 yfinance-0.1.59
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from Investar import Analyzer

# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()


df = pdr.get_data_yahoo('005930.KS', '2017-01-01')  # ①

plt.figure(figsize=(9, 6))
plt.subplot(2, 1, 1)  # ② 
plt.title('Samsung Electronics (Yahoo Finance)')
plt.plot(df.index, df['Close'], 'c', label='Close')  # ③
plt.plot(df.index, df['Adj Close'], 'b--', label='Adj Close')  # ④
plt.legend(loc='best')

plt.subplot(2, 1, 2)  # ⑤
plt.bar(df.index, df['Volume'], color='g', label='Volume')  # ⑥
plt.legend(loc='best')
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
import pymysql

connection = pymysql.connect(host='localhost', port=3306, db='INVESTAR', 
    user='root', passwd='woal3581', autocommit=True)  

cursor = connection.cursor()
cursor.execute("SELECT VERSION();")
result = cursor.fetchone()

print ("MariaDB version : {}".format(result))

connection.close()
# Out:
# MariaDB version : ('10.5.9-MariaDB',)

# %%
# pip install pymysql

# %%
Analyzer.MarketDB()

# %%
mk = Analyzer.MarketDB()  # ②
df = mk.get_daily_price('005930', '2021-02-21', '2021-03-31')  # ③
df
# Out:
#               code        date   open   high    low  close  diff    volume
# date
# 2021-03-22  005930  2021-03-22  82000  82300  81700  82000   100  12670506
# 2021-03-23  005930  2021-03-23  82600  82900  81800  81800   200  13299907
# 2021-03-24  005930  2021-03-24  81000  81600  80700  81000   800  17926638
# 2021-03-25  005930  2021-03-25  81000  82100  80800  81200   200  14758826
# 2021-03-26  005930  2021-03-26  81400  81600  81000  81500   300  12845778
# 2021-03-29  005930  2021-03-29  81700  81700  81000  81600   100  14952134
# 2021-03-30  005930  2021-03-30  81600  82300  81300  82200   600  13121698
# 2021-03-31  005930  2021-03-31  82400  82700  81400  81400   800  17240518

# %%
import matplotlib.pyplot as plt

mk = Analyzer.MarketDB()  # ②
df = mk.get_daily_price('005930', '2021-02-21', '2021-04-02')  # ③

plt.figure(figsize=(9, 6))
plt.subplot(2, 1, 1)
plt.title('Samsung Electronics (Investar Data)')
plt.plot(df.index, df['close'], 'c', label='Close')  # ④
plt.legend(loc='best')

plt.subplot(2, 1, 2)
plt.bar(df.index, df['volume'], color='g', label='Volume')
plt.legend(loc='best')
plt.show()
